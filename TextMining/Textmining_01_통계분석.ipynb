# %% [markdown]
# 통계분석

# %%
#와인품질 등급 예측하기

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.read_csv('./7장_data/winequality-red.csv', sep=';')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_red = pd.read_csv('./7장_data/winequality-red.csv', sep=';',header=0)
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#전처리한 파일 >>csv파일로 변환

df_red.to_csv('./7장_data/winequality-red-mod.csv', index=False)

# %%
df_white = pd.read_csv('./7장_data/winequality-white.csv',sep=';', header=0)

# %%
df_white.to_csv('./7장_data/winequality-white-mod.csv', index=False)

# %%
df_red.insert(0, column='type', value='red')
df_red.head(3)
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5

# %%
df_white.insert(0, column='type', value='white')
df_white.head(3)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6

# %%
print(df_red.shape)
print(df_white.shape)
# Out:
# (1599, 13)
# (4898, 13)

# %%
#두 개의 csv파일 병합

pd.concat([df_red, df_white])
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       red            7.4              0.70         0.00             1.9
# 1       red            7.8              0.88         0.00             2.6
# 2       red            7.8              0.76         0.04             2.3
# 3       red           11.2              0.28         0.56             1.9
# 4       red            7.4              0.70         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 4893  white            6.2              0.21         0.29             1.6
# 4894  white            6.6              0.32         0.36             8.0
# 4895  white            6.5              0.24         0.19             1.2
# 4896  white            5.5              0.29         0.30             1.1
# 4897  white            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
raw = pd.concat([df_red, df_white])
wine = raw.copy()
wine.head(3)
# Out:
#   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5

# %%
wine.shape
# Out:
# (6497, 13)

# %%
wine.to_csv('./7장_data/wine.csv', index=False)

# %% [markdown]
# EDA(탐색적 데이터 분석) Exploratory Data Analysis

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB

# %%
#컬럼 이름의 띄어쓰기를 밑줄로 바꾸기

wine.columns = wine.columns.str.replace(' ', '_')
wine.head(3)
# Out:
#   type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
wine['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9], dtype=int64)

# %%
sorted(wine['quality'].unique())
#default : 오름차순
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
wine['quality'].value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# 데이터 모델링

# %%
#describe() 함수로 그룹별 비교

wine.groupby('type')['quality'].describe()
# Out:
#         count      mean       std  min  25%  50%  75%  max
# type
# red    1599.0  5.636023  0.807569  3.0  5.0  6.0  6.0  8.0
# white  4898.0  5.877909  0.885639  3.0  5.0  6.0  6.0  9.0

# %%
wine.groupby('type')['quality'].mean() #평균값
# Out:
# type
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
wine.groupby('type')['quality'].std() #표준편차
# Out:
# type
# red      0.807569
# white    0.885639
# Name: quality, dtype: float64

# %%
#agg()두가지의 집계함수 쓸수 있음
wine.groupby('type')['quality'].agg(['mean','std'])
# Out:
#            mean       std
# type
# red    5.636023  0.807569
# white  5.877909  0.885639

# %%
# agg()예시

data = {
    'A' : [1,2,3,4],
    'B' : [10,20,30,40],
    'C' : [100,200,300,400]
}
temp = pd.DataFrame(data)
temp.head()
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400

# %%
temp.agg(['mean','sum'])
# Out:
#          A      B       C
# mean   2.5   25.0   250.0
# sum   10.0  100.0  1000.0

# %% [markdown]
# 독립표본 T검정

# %%
# !pip install statsmodels

# %%
from scipy import stats
from statsmodels.formula.api import ols, glm

# %%
wine.head(3)
# Out:
#   type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  red            7.4              0.70         0.00             1.9
# 1  red            7.8              0.88         0.00             2.6
# 2  red            7.8              0.76         0.04             2.3
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5

# %%
red_wine_quality = wine.loc[wine['type'] == 'red', 'quality']
white_wine_quality = wine.loc[wine['type'] == 'white', 'quality']

# %%
stats.ttest_ind(red_wine_quality, white_wine_quality, equal_var=False)
# pvalue=8.168348870049682e-24 (<0.05)
# >> 두 집단(레드와인, 화이트와인)간 평균 차이가 있다
# >> 귀무가설(H0) : 두 집단간 평균의 차이는 없다 >> 기각 됨
# >> 대립가설로 설정한 H1(Ha) : 두 집단간 평균의 차이가 있다가 채택됨
# 단, 일반화는 아님 : 전제조건!
# Out:
# TtestResult(statistic=-10.149363059143164, pvalue=8.168348870049682e-24, df=2950.750452166697)

# %% [markdown]
# 회귀분석

# %%
wine.columns
# Out:
# Index(['type', 'fixed_acidity', 'volatile_acidity', 'citric_acid',
#        'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
#        'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
rformula = 'quality ~ fixed_acidity + volatile_acidity + citric_acid + \
            residual_sugar + chlorides +free_sulfur_dioxide + \
            total_sulfur_dioxide + density + pH + sulphates + alcohol'

# %%
result = ols(rformula, data=wine).fit().summary()

# %%
result
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     243.3
# Date:                Tue, 28 May 2024   Prob (F-statistic):               0.00
# Time:                        16:10:55   Log-Likelihood:                -7215.5
# No. Observations:                6497   AIC:                         1.445e+04
# Df Residuals:                    6485   BIC:                         1.454e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 유효하지 않은 citric_acid/chlorides 제거

# %%
rformula = 'quality ~ fixed_acidity + volatile_acidity  + \
            residual_sugar + free_sulfur_dioxide + \
            total_sulfur_dioxide + density + pH + sulphates + alcohol'

# %%
result = ols(rformula, data=wine).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     296.7
# Date:                Tue, 28 May 2024   Prob (F-statistic):               0.00
# Time:                        16:10:55   Log-Likelihood:                -7217.8
# No. Observations:                6497   AIC:                         1.446e+04
# Df Residuals:                    6487   BIC:                         1.452e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 회귀분석 모델로 새로운 샘플 품질 등급 예측하기

# %%
wine.columns
# Out:
# Index(['type', 'fixed_acidity', 'volatile_acidity', 'citric_acid',
#        'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
#        'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
wine.columns.difference(['quality','type'])
#difference() : 데이터프레임만 사용
#quality와 type에 속하지 않은 열들을 반환
# Out:
# Index(['alcohol', 'chlorides', 'citric_acid', 'density', 'fixed_acidity',
#        'free_sulfur_dioxide', 'pH', 'residual_sugar', 'sulphates',
#        'total_sulfur_dioxide', 'volatile_acidity'],
#       dtype='object')

# %%
condition = wine.columns.difference(['quality','type'])
wine[condition]
# Out:
#       alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0         9.4      0.076         0.00  0.99780            7.4
# 1         9.8      0.098         0.00  0.99680            7.8
# 2         9.8      0.092         0.04  0.99700            7.8
# 3         9.8      0.075         0.56  0.99800           11.2
# 4         9.4      0.076         0.00  0.99780            7.4
# ...       ...        ...          ...      ...            ...
# 4893     11.2      0.039         0.29  0.99114            6.2
# 4894      9.6      0.047         0.36  0.99490            6.6
# 4895      9.4      0.041         0.19  0.99254            6.5
# 4896     12.8      0.022         0.30  0.98869            5.5
# 4897     11.8      0.020         0.38  0.98941            6.0
#
#       free_sulfur_dioxide    pH  residual_sugar  sulphates  \
# 0                    11.0  3.51             1.9       0.56
# 1                    25.0  3.20             2.6       0.68
# ...

# %%
sample1 = wine[condition]
sample1.head(3)
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0      9.4      0.076         0.00   0.9978            7.4
# 1      9.8      0.098         0.00   0.9968            7.8
# 2      9.8      0.092         0.04   0.9970            7.8
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 11.0  3.51             1.9       0.56                  34.0
# 1                 25.0  3.20             2.6       0.68                  67.0
# 2                 15.0  3.26             2.3       0.65                  54.0
#
#    volatile_acidity
# 0              0.70
# 1              0.88
# 2              0.76

# %%
sample1[:5][:]
# Out:
#    alcohol  chlorides  citric_acid  density  fixed_acidity  \
# 0      9.4      0.076         0.00   0.9978            7.4
# 1      9.8      0.098         0.00   0.9968            7.8
# 2      9.8      0.092         0.04   0.9970            7.8
# 3      9.8      0.075         0.56   0.9980           11.2
# 4      9.4      0.076         0.00   0.9978            7.4
#
#    free_sulfur_dioxide    pH  residual_sugar  sulphates  total_sulfur_dioxide  \
# 0                 11.0  3.51             1.9       0.56                  34.0
# 1                 25.0  3.20             2.6       0.68                  67.0
# 2                 15.0  3.26             2.3       0.65                  54.0
# 3                 17.0  3.16             1.9       0.58                  60.0
# 4                 11.0  3.51             1.9       0.56                  34.0
#
#    volatile_acidity
# 0              0.70
# 1              0.88
# 2              0.76
# 3              0.28
# 4              0.70

# %%
sample1 = sample1[:5][:]

# %%
y_pred = result.predict(sample1)

# %%
y_pred
#회귀분석 모델 (ols)이 예측한 결과
# Out:
# 0    4.975950
# 1    4.905454
# 2    5.016237
# 3    5.687222
# 4    4.975950
# dtype: float64

# %%
wine[:5]['quality']
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %% [markdown]
# 결과 시각화

# %%
#와인 유형(레드, 화이트)따른 품질 등급 히스토그램 그리기

import seaborn as sns

sns.set_style('dark')
sns.displot(red_wine_quality, kde=True, color='red', label='red_wine')
sns.displot(white_wine_quality, kde=True, color='Silver' , label='white_wine')
plt.title('Quality of Wine Type')
plt.legend()
plt.show()

# %% [markdown]
# 부분 회귀 플롯(plot) 시각화

# %%
import statsmodels.api as sm

# %%
wine.columns
# Out:
# Index(['type', 'fixed_acidity', 'volatile_acidity', 'citric_acid',
#        'residual_sugar', 'chlorides', 'free_sulfur_dioxide',
#        'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
#fixed_acidity >> quality 에 미치는 영향력 시각화

list(set(wine.columns).difference(set(['quality','fixed_acidity'])))
# Out:
# ['pH',
#  'free_sulfur_dioxide',
#  'residual_sugar',
#  'type',
#  'volatile_acidity',
#  'alcohol',
#  'sulphates',
#  'total_sulfur_dioxide',
#  'density',
#  'chlorides',
#  'citric_acid']

# %%
others = list(set(wine.columns).difference(set(['quality','fixed_acidity'])))

# %%
p, resids = sm.graphics.plot_partregress('quality','fixed_acidity',others,data=wine, ret_coords=True)

#plot.partregress
#p : 데이터 포인트
#regids : 잔차
# others : 통제변수
#'quality' : 종속변수, 'fixed_acidity : 독립변수
#ret_coords=True : 부분 회귀 플롯의 점들의 좌표변환

# %%
#각 독립변수가 종속변수 quality에 미치는 영향력 시각화

fig = plt.figure(figsize=(8,14))
sm.graphics.plot_partregress_grid(result, fig=fig)
plt.show()

# %% [markdown]
# 상관분석 히트맵

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
raw = sns.load_dataset('titanic')
titanic = raw.copy()
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
path = '/content/drive/MyDrive/통계분석/data'

# %%
pwd
# Out:
# 'd:\\MulCam\\10_빅데이터분석'

# %%
titanic.to_csv('./titanic.csv', index=False)

# %% [markdown]
# 데이터 준비

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#age 결측값 처리
#mean, median 중 선택

titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic['age'].mean()
# Out:
# 29.69911764705882

# %%
titanic['age'].median()
# Out:
# 28.0

# %%
# age 열의 결측값을 평균으로 치환하기

titanic['age'].fillna(titanic['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
# age 열의 결측값을 중앙값으로 치환하기

titanic['age'].fillna(titanic['age'].median())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# 중앙값 치환하기로 한 경우

# %%
titanic['age'] = titanic['age'].fillna(titanic['age'].median())
titanic['age'][:3]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# Name: age, dtype: float64

# %%
titanic['age'].isna().sum()
# Out:
# 0

# %%
titanic['embarked'].value_counts() #최빈값으로 대체
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic['embarked'] = titanic['embarked'].fillna('S')

# %%
titanic['embark_town']
#embarked랑 중복되는 컬럼
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
#중복되는 속성 정보 제거
del titanic['embark_town']

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'alive', 'alone'],
#       dtype='object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    object
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    object
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  deck        203 non-null    category
#  12  alive       891 non-null    object
#  13  alone       891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(4)
# memory usage: 73.7+ KB

# %%
print(203/891) #notnull
print(1-(203/891)) #null
# Out:
# 0.22783389450056116
# 0.7721661054994389

# %%
titanic['deck'][:3]
# Out:
# 0    NaN
# 1      C
# 2    NaN
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic['deck'].isna().sum()
# Out:
# 688

# %%
titanic['deck'].value_counts()
# Out:
# deck
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: count, dtype: int64

# %%
del titanic['deck']

# %%
titanic.isna().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %% [markdown]
# 데이터탐색(EDA)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    object
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    object
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  alive       891 non-null    object
#  12  alone       891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(4)
# memory usage: 72.5+ KB

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'alive', 'alone'],
#       dtype='object')

# %%
titanic['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic['survived'][titanic['sex']=='male'].value_counts()
# Out:
# survived
# 0    468
# 1    109
# Name: count, dtype: int64

# %%
titanic['survived'][titanic['sex']=='female'].value_counts()
# Out:
# survived
# 1    233
# 0     81
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(12,6))

titanic['survived'][titanic['sex']=='male'].value_counts().plot.pie(
    explode=[0, 0.1], colors=['#FF9999', '#66B3FF'],autopct='%1.1f%%',labels=['Died','Survived'] ,ax=ax[0])

titanic['survived'][titanic['sex']=='female'].value_counts().plot.pie(
    explode=[0, 0.1], colors=['#66B3FF', '#FF9999'],autopct='%1.1f%%',labels=['Survived','Died'], startangle=180, ax=ax[1])

# explode = [0,0.1] : 파이차트의 두 번째 조각을 0.1만큼 떨어트리기
# autopct = %1.1f%% : 자동(auto)으로 퍼센트 비율 표시 (백분율을 소수점 첫째자리까지 표시)

# 범례 추가
ax[1].legend(loc='upper right', labels=['Survived','Died'])


ax[0].set_title('Survived (Male)')
ax[1].set_title('Survived (Female)')

plt.show()

# %%
sns.countplot(x='pclass', hue='sex', data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %% [markdown]
# 데이터 모델링

# %%
titanic['sex'] = titanic['sex'].str.replace('female','1').str.replace('male','0')

# %%
titanic['sex'] = titanic['sex'].astype('int')

# %%
titanic['embarked'] = titanic['embarked'].str.replace('S','1').str.replace('C','2').str.replace('Q','3')

# %%
titanic['embarked'] = titanic['embarked'].astype('int')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    int32
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    int32
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  alive       891 non-null    object
#  12  alone       891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int32(2), int64(4), object(2)
# memory usage: 65.5+ KB

# %%
df = titanic[['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked']]

# %%
#상관분석

df.corr(method='pearson')
# Out:
#           survived    pclass       sex       age     sibsp     parch  \
# survived  1.000000 -0.338481  0.543351 -0.064910 -0.035322  0.081629
# pclass   -0.338481  1.000000 -0.131900 -0.339898  0.083081  0.018443
# sex       0.543351 -0.131900  1.000000 -0.081163  0.114631  0.245489
# age      -0.064910 -0.339898 -0.081163  1.000000 -0.233296 -0.172482
# sibsp    -0.035322  0.083081  0.114631 -0.233296  1.000000  0.414838
# parch     0.081629  0.018443  0.245489 -0.172482  0.414838  1.000000
# fare      0.257307 -0.549500  0.182333  0.096688  0.159651  0.216225
# embarked  0.106811  0.045702  0.116569 -0.009165 -0.059961 -0.078665
#
#               fare  embarked
# survived  0.257307  0.106811
# pclass   -0.549500  0.045702
# sex       0.182333  0.116569
# age       0.096688 -0.009165
# sibsp     0.159651 -0.059961
# parch     0.216225 -0.078665
# fare      1.000000  0.062142
# embarked  0.062142  1.000000

# %%
df_corr = df.corr(method='pearson')

# %%
df_corr.to_csv('/titanic_corr.csv', index=False)

# %% [markdown]
# 상관계수 구하기

# %%
titanic['adult_male']
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: adult_male, Length: 891, dtype: bool

# %%
titanic['survived'].corr(titanic['adult_male'])
# Out:
# -0.5570800422053258

# %%
titanic['survived'].corr(titanic['fare'])
# Out:
# 0.25730652238496227

# %% [markdown]
# 결과 시각화

# %%
sns.pairplot(titanic)

# %%
sns.pairplot(titanic, hue = 'survived')

# %% [markdown]
# 두 변수의 상관관계 시각화하기

# %%
#객실등급(pclass) 와 생존(survived) 상관관계
#catplot()

sns.catplot(x='pclass', y='survived', data=titanic)

# %%
#변수 사이의 상관관계를 히트맵 시각화하기

def category_age(x):
    if x < 10:
        return 0
    elif x < 20:
        return 1
    elif x < 30:
        return 2
    elif x < 40:
        return 3
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    else:
        return 7

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
titanic['age'].apply(category_age)
# Out:
# 0      2
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 886    2
# 887    1
# 888    2
# 889    2
# 890    3
# Name: age, Length: 891, dtype: int64

# %%
titanic['age2'] = titanic['age'].apply(category_age)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'alive', 'alone', 'age2'],
#       dtype='object')

# %%
heatmap_data = titanic[['survived', 'sex', 'age2', 'pclass','fare']]

# %%
heatmap_data.head(3)
# Out:
#    survived  sex  age2  pclass     fare
# 0         0    0     2       3   7.2500
# 1         1    1     3       1  71.2833
# 2         1    1     2       3   7.9250

# %%
colormap = plt.cm.RdBu
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True,
            annot_kws={'size':10})

plt.show()
